# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

pd.pandas.set_option('display.max_columns',None)

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
           '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# %%
dataset = pd.read_csv('../Advanced-House-Price-Prediction-/train.csv')
dataset.shape
# Out:
# (1460, 81)

# %%
from sklearn.model_selection import train_test_split
# 10% validating 90% training
X_train, X_test, y_train, y_test = train_test_split(dataset,dataset['SalePrice'],test_size=0.1,random_state=0)

# %%
X_train.shape , X_test.shape
# Out:
# ((1314, 81), (146, 81))

# %%
features_nan = [feature for feature in dataset.columns if dataset[feature].isnull().sum()>1 and dataset[feature].dtypes=='O']
for feature in features_nan:
    print("missing features are {} and {} % of it".format(feature,np.round(dataset[feature].isnull().mean(),4)))
# Out:
# missing features are Alley and 0.9377 % of it
# missing features are MasVnrType and 0.0055 % of it
# missing features are BsmtQual and 0.0253 % of it
# missing features are BsmtCond and 0.0253 % of it
# missing features are BsmtExposure and 0.026 % of it
# missing features are BsmtFinType1 and 0.0253 % of it
# missing features are BsmtFinType2 and 0.026 % of it
# missing features are FireplaceQu and 0.4726 % of it
# missing features are GarageType and 0.0555 % of it
# missing features are GarageFinish and 0.0555 % of it
# missing features are GarageQual and 0.0555 % of it
# missing features are GarageCond and 0.0555 % of it
# missing features are PoolQC and 0.9952 % of it
# missing features are Fence and 0.8075 % of it
# missing features are MiscFeature and 0.963 % of it

# %%
#replace missing
def replace_cat_feature(dataset, features_nan):
    data=dataset.copy()
    data[features_nan]=data[features_nan].fillna('missing')
    return data

dataset=replace_cat_feature(dataset,features_nan)
dataset[features_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
numerical_with_nan=[feature for feature in dataset.columns if dataset[feature].isnull().sum() > 1 and dataset[feature].dtypes!='O']
                   
for feature in numerical_with_nan:
    print("{} of val {}%".format(feature,np.around(dataset[feature].isnull().mean(),4)))
# Out:
# LotFrontage of val 0.1774%
# MasVnrArea of val 0.0055%
# GarageYrBlt of val 0.0555%

# %%
# replace numerical missing
for feature in numerical_with_nan:
    median_value=dataset[feature].median()
    
    #create new feature to caputure nan val
    dataset[feature+'nan']=np.where(dataset[feature].isnull(),1,0)
    dataset[feature].fillna(median_value,inplace=True)
    
dataset[numerical_with_nan].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
dataset.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  missing      Reg
# 1   2          20       RL         80.0     9600   Pave  missing      Reg
# 2   3          60       RL         68.0    11250   Pave  missing      IR1
# 3   4          70       RL         60.0     9550   Pave  missing      IR1
# 4   5          60       RL         84.0    14260   Pave  missing      IR1
# 5   6          50       RL         85.0    14115   Pave  missing      IR1
# 6   7          20       RL         75.0    10084   Pave  missing      Reg
# 7   8          60       RL         69.0    10382   Pave  missing      IR1
# 8   9          50       RM         51.0     6120   Pave  missing      Reg
# 9  10         190       RL         50.0     7420   Pave  missing      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
#temporal variable (date time variables)

for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
    dataset[feature]=dataset['YrSold']-dataset[feature]

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  missing      Reg
# 1   2          20       RL         80.0     9600   Pave  missing      Reg
# 2   3          60       RL         68.0    11250   Pave  missing      IR1
# 3   4          70       RL         60.0     9550   Pave  missing      IR1
# 4   5          60       RL         84.0    14260   Pave  missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
dataset[['YearBuilt','YearRemodAdd', 'GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %%
# Numerical Variables

dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  missing      Reg
# 1   2          20       RL         80.0     9600   Pave  missing      Reg
# 2   3          60       RL         68.0    11250   Pave  missing      IR1
# 3   4          70       RL         60.0     9550   Pave  missing      IR1
# 4   5          60       RL         84.0    14260   Pave  missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
categorical_features=[feature for feature in dataset.columns if dataset[feature].dtype=='O']

# %%
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
for feature in categorical_features:
    temp = dataset.groupby(feature)['SalePrice'].count()/len(dataset)
    print('temp ',temp)
    temp_df = temp[temp>0.01].index
    print(' temp df  ',temp_df)
    dataset[feature]=np.where(dataset[feature].isin(temp_df),dataset[feature],'Rare_var')
# Out:
# MSZoning
# C (all)    0.006849
# FV         0.044521
# RH         0.010959
# RL         0.788356
# RM         0.149315
# Name: SalePrice, dtype: float64
# Index(['FV', 'RH', 'RL', 'RM'], dtype='object', name='MSZoning')
# Street
# Grvl    0.00411
# Pave    0.99589
# Name: SalePrice, dtype: float64
# Index(['Pave'], dtype='object', name='Street')
# Alley
# Grvl       0.034247
# Pave       0.028082
# missing    0.937671
# Name: SalePrice, dtype: float64
# Index(['Grvl', 'Pave', 'missing'], dtype='object', name='Alley')
# LotShape
# IR1    0.331507
# IR2    0.028082
# IR3    0.006849
# Reg    0.633562
# Name: SalePrice, dtype: float64
# Index(['IR1', 'IR2', 'Reg'], dtype='object', name='LotShape')
# LandContour
# Bnk    0.043151
# HLS    0.034247
# Low    0.024658
# Lvl    0.897945
# Name: SalePrice, dtype: float64
# Index(['Bnk', 'HLS', 'Low', 'Lvl'], dtype='object', name='LandContour')
# Utilities
# AllPub    0.999315
# NoSeWa    0.000685
# Name: SalePrice, dtype: float64
# ...
