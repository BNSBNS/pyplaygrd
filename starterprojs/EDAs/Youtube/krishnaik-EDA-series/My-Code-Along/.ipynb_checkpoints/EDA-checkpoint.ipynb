# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

pd.pandas.set_option('display.max_columns',None)

# %%
#getting the dataset
dataset = pd.read_csv('../Advanced-House-Price-Prediction-/train.csv')
dataset.shape
# Out:
# (1460, 81)

# %% [markdown]
# here shows it has 1460 row, 81 column

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# dataset.columns

# enumerate, start =1 to list all the columns

for idx,col in enumerate(dataset.columns, start=1):
    print(idx, ' ',col)
# Out:
# 1   Id
# 2   MSSubClass
# 3   MSZoning
# 4   LotFrontage
# 5   LotArea
# 6   Street
# 7   Alley
# 8   LotShape
# 9   LandContour
# 10   Utilities
# 11   LotConfig
# 12   LandSlope
# 13   Neighborhood
# 14   Condition1
# 15   Condition2
# 16   BldgType
# 17   HouseStyle
# 18   OverallQual
# 19   OverallCond
# 20   YearBuilt
# 21   YearRemodAdd
# 22   RoofStyle
# 23   RoofMatl
# 24   Exterior1st
# 25   Exterior2nd
# 26   MasVnrType
# 27   MasVnrArea
# 28   ExterQual
# 29   ExterCond
# 30   Foundation
# 31   BsmtQual
# 32   BsmtCond
# 33   BsmtExposure
# 34   BsmtFinType1
# 35   BsmtFinSF1
# 36   BsmtFinType2
# 37   BsmtFinSF2
# 38   BsmtUnfSF
# 39   TotalBsmtSF
# 40   Heating
# 41   HeatingQC
# 42   CentralAir
# 43   Electrical
# 44   1stFlrSF
# 45   2ndFlrSF
# 46   LowQualFinSF
# 47   GrLivArea
# 48   BsmtFullBath
# 49   BsmtHalfBath
# 50   FullBath
# 51   HalfBath
# 52   BedroomAbvGr
# 53   KitchenAbvGr
# 54   KitchenQual
# 55   TotRmsAbvGrd
# 56   Functional
# 57   Fireplaces
# ...

# %% [markdown]
# there are many columns, now is time to check quality of data, ie any null

# %%
# https://stackoverflow.com/questions/53283142/understand-df-isnull-mean-in-python
# why is isnull.mean 

features_with_na = [features for features in dataset.columns if dataset[features].isnull().sum()>1]

for feature in features_with_na:
    print(feature, np.round(dataset[feature].isnull().mean(),4), '  missing values')
# Out:
# LotFrontage 0.1774   missing values
# Alley 0.9377   missing values
# MasVnrType 0.0055   missing values
# MasVnrArea 0.0055   missing values
# BsmtQual 0.0253   missing values
# BsmtCond 0.0253   missing values
# BsmtExposure 0.026   missing values
# BsmtFinType1 0.0253   missing values
# BsmtFinType2 0.026   missing values
# FireplaceQu 0.4726   missing values
# GarageType 0.0555   missing values
# GarageYrBlt 0.0555   missing values
# GarageFinish 0.0555   missing values
# GarageQual 0.0555   missing values
# GarageCond 0.0555   missing values
# PoolQC 0.9952   missing values
# Fence 0.8075   missing values
# MiscFeature 0.963   missing values

# %%
a = dataset['LotFrontage'].isnull().mean()
print(a)
# Out:
# 0.1773972602739726

# %% [markdown]
# find relationship between missing values and saleprice

# %%
for feature in features_with_na:
    data = dataset.copy()
    
#     put 1 if null , 0 if not
    data[feature] = np.where(data[feature].isnull(),1,0)
#     calculate sale price where info is missin or present
# https://www.geeksforgeeks.org/python-pandas-dataframe-groupby/
    colors = ['red','blue']
    data.groupby(feature)['SalePrice'].median().plot.bar(color=colors)
    plt.title(feature)
    plt.show()

# %%
# print("id of houses {}".format(len(dataset.Id))) # also works
# not sure why i need this
print("id of houses {}".format(len(dataset['Id'])))
# Out:
# id of houses 1460

# %% [markdown]
# check how many numerical features

# %%
numerical_features = [feature for feature in dataset.columns if dataset[feature].dtypes != 'O']
# print(numerical_features)

# %%
dataset[numerical_features].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
Temporal Variables(Eg: Datetime Variables)
